# %% [markdown]
# # Pandas - Week 3

# %% [markdown]
# ***

# %% [markdown]
# ## Membagi data frame menjadi dua secara acak

# %% [markdown]
# ### 1. Import Modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Persiapan Data Frame

# %%
n_rows = 10
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns = cols)

df
# Out:
#     A   B   C   D   E
# 0  19  15   9   1   3
# 1  14  14  18  18   1
# 2  18  16  19  17   6
# 3  16   8   2   7  10
# 4   8  12  17   3  15
# 5   6  19  17  11   5
# 6   4  19  18  11   2
# 7  13   6   1   9  14
# 8   9  12   9  12  15
# 9   3   4   9  13   9

# %% [markdown]
# ### 3. Membagi Data Frame menjadi dua secara acak berdasarkan proporsi tertentu.

# %%
df.shape
# Out:
# (10, 5)

# %%
proporsi = 0.7 #Penentuan proposi: 70% untuk Data Frame 1, dan 30% untuk DF 2.
df_1 = df.sample(frac=proporsi)
df_2 = df.drop(df_1.index) #Menghapus baris yang sudah diadopsi oleh df_1.

print(f'df_1 shape: {df_1.shape}')
print(f'df_2 shape: {df_2.shape}')
# Out:
# df_1 shape: (7, 5)
# df_2 shape: (3, 5)

# %% [markdown]
# Fungsi `sample()` merupakan method yang akan mengambil baris secara acak berdasarkan proporsi yang sudah ditentukan dari baris-baris dataframe DF dan akan ditampung di DF_1.

# %%
df_1
# Out:
#     A   B   C   D   E
# 7  13   6   1   9  14
# 5   6  19  17  11   5
# 6   4  19  18  11   2
# 3  16   8   2   7  10
# 0  19  15   9   1   3
# 1  14  14  18  18   1
# 2  18  16  19  17   6

# %%
df_2
# Out:
#    A   B   C   D   E
# 4  8  12  17   3  15
# 8  9  12   9  12  15
# 9  3   4   9  13   9

# %% [markdown]
# ***

# %% [markdown]
# ## Mengganti nama kolom pada Data Frame berdasarkan pola

# %% [markdown]
# ### 1. Import modules

# %%
import pandas as pd

# %% [markdown]
# ### 2. Persiapan Data Frame

# %%
df2 = pd.read_csv('./data/titanicfull.csv')
df2.columns = ('Pclass', 'Survival status', 'full Name', 'Sex ', ' Age', 'Sib SP', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked')

df2_backup = df2.copy(deep=True)

df2.head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                0             Allison, Mr. Hudson Joshua Creighton
# 4       1                0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#      Sex     Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# ### 3. Menggunakan lowercase untuk nama kolom dan mengganti spasi dengan `_`

# %%
df2.columns = df2.columns.str.replace(' ', '_').str.lower()
df2.head()
# Out:
#    pclass  survival_status                                        full_name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                0             Allison, Mr. Hudson Joshua Creighton
# 4       1                0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#      sex_   _age  sib_sp  parch  ticket      fare    cabin embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# Method `str.replace()` akan mengganti karakter yang dituju menjadi karakter yang diinginkan. Dalam kasus ini, karakter spasi akan diganti dengan underscore. Sedangkan method `str.lower()` akan mengganti nama kolom menjadi lowercase.

# %% [markdown]
# ### 4. Menghilangkan kelebihan spasi pada nama kolom.

# %%
df2 = df2_backup.copy(deep=True)
df2.columns = df2.columns.str.lower().str.strip().str.replace(' ', '_')

df2.head()
# Out:
#    pclass  survival_status                                        full_name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                0             Allison, Mr. Hudson Joshua Creighton
# 4       1                0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex    age  sib_sp  parch  ticket      fare    cabin embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# Method `str.strip()` akan memotong kelebihan spasi di sisi kanan dan sisi kiri.

# %% [markdown]
# ***

# %% [markdown]
# ## Seleksi kolom dan baris pada Data Frame menggunakan `loc`

# %% [markdown]
# ### 1. Import modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Persiapan Data Frame

# %%
n_rows = 10
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns = cols)

df
# Out:
#     A   B   C   D   E
# 0  11  10   1  12  11
# 1   1  19   8   8  15
# 2  12   7   6  14  15
# 3  16  18   4  17  10
# 4  10  11  18   1   7
# 5   8   4   7   3  11
# 6  10  19  15  17   4
# 7  12  15  16  13  10
# 8  12  16   6   2  15
# 9  10  16   3   7   2

# %% [markdown]
# ### 3. Seleksi kolom dan baris menggunakan `loc`

# %%
df.loc[[0, 3, 4], ['B', 'E']]
# Out:
#     B   E
# 0  10  11
# 3  18  10
# 4  11   7

# %% [markdown]
# `loc` terbagi menjadi dua bagian besar dimana setiap bagiannya dipisahkan dengan tanda koma. Bagian pertama digunakan untuk mengatur baris, dan bagian kedua digunakan untuk mengatur kolom.

# %% [markdown]
# ### 4. Seleksi baris dengan kondisi

# %%
df.loc[df['B']>10, ['B', 'D', 'E']]
# Out:
#     B   D   E
# 1  19   8  15
# 3  18  17  10
# 4  11   1   7
# 6  19  17   4
# 7  15  13  10
# 8  16   2  15
# 9  16   7   2

# %% [markdown]
# Pada kasus ini, baris yang ditampilkan adalah baris yang memiliki nilai di atas 10 di kolom B.

# %% [markdown]
# ### 5. Slicing Data Frame dengan `loc`

# %%
df.loc[0:4, 'B':'D'] #Slicing dari baris ke 0 sampai ke 4, dan mulai dari kolom B ke D.
# Out:
#     B   C   D
# 0  10   1  12
# 1  19   8   8
# 2   7   6  14
# 3  18   4  17
# 4  11  18   1
